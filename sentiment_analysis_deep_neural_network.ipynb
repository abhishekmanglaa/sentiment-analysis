# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekmanglaa/sentiment-analysis/blob/main/sentiment_analysis_deep_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Deep Learning network for sentiment analysis of the Sentiment Data From Kaggle

# %%
import json
import tensorflow as tf
import csv
import random
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

# Hyperparameter
embedding_dim = 100
max_length = 16
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size= 160000 #TODO this is the size of the training data set which you will get below
test_portion=.1

corpus = []

# %% [markdown]
# ## Loading the raw data from Kaggle.
#
# Cleaning the data

# %%
# Ingest a cleaned version of the data set from https://www.kaggle.com/kazanova/sentiment140

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv \
    -O /tmp/training_cleaned.csv

num_sentences = 0

with open("/tmp/training_cleaned.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        list_item=[]
        list_item.append(row[5])
        list_item.append(0) if row[0] == '0' else list_item.append(1)
        # TODO: 1st item in list_item is the text found in index [5]; 2nd item is the label: it should be 0 if the first item of the row is '0'. Otherwise, the label should be '1'

        num_sentences = num_sentences + 1
        corpus.append(list_item)
# Out:
# --2020-10-27 00:39:13--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.7.240, 172.217.12.240, 172.217.13.240, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.7.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238942690 (228M) [application/octet-stream]
# Saving to: ‘/tmp/training_cleaned.csv’
#
# /tmp/training_clean 100%[===================>] 227.87M  81.9MB/s    in 2.8s
#
# 2020-10-27 00:39:16 (81.9 MB/s) - ‘/tmp/training_cleaned.csv’ saved [238942690/238942690]

# %% [markdown]
# ## Preparing the training and test data

# %%
sentences=[]
labels=[]
random.shuffle(corpus)
for x in range(training_size):
    sentences.append(corpus[x][0])
    labels.append(corpus[x][1])

tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size=len(word_index) 

sequences = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(sequences, maxlen=max_length, truncating=trunc_type)

split = int(test_portion * training_size)

test_sequences = padded[:split]
training_sequences = padded[split:]
test_labels = labels[:split]
training_labels = labels[split:]

# %%
# Note this is the 100 dimension version of GloVe from Stanford
# Laurence Moroney unzipped and hosted it on his site to make this notebook easier
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    -O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/tmp/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;

embeddings_matrix = np.zeros((vocab_size+1, embedding_dim));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# --2020-10-27 00:54:45--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.164.176, 172.217.2.112, 172.217.7.176, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.164.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 347116733 (331M) [text/plain]
# Saving to: ‘/tmp/glove.6B.100d.txt’
#
# /tmp/glove.6B.100d. 100%[===================>] 331.04M  88.1MB/s    in 3.8s
#
# 2020-10-27 00:54:49 (88.1 MB/s) - ‘/tmp/glove.6B.100d.txt’ saved [347116733/347116733]

# %% [markdown]
# ## Model architecture and training

# %%
training_labels = np.asarray(training_labels)
test_labels = np.asarray(test_labels)


model = tf.keras.Sequential([
    #TODO 
    # Embedding layer
    tf.keras.layers.Embedding(vocab_size+1, embedding_dim, input_length=max_length, weights=[embeddings_matrix], trainable=False),
    # Dropout of 20%
    tf.keras.layers.Dropout(0.2),
    # Conv1D layer
    tf.keras.layers.Conv1D(128, 3, activation='relu'),
    # MaxPooling1D with size 4
    tf.keras.layers.MaxPooling1D(4),
    # LSTM layer
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    # Output Dense layer
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()

num_epochs = 50
history = model.fit(training_sequences, training_labels, epochs=num_epochs, validation_data=(test_sequences, test_labels), verbose=2)

print("Training Complete")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 16, 100)           13832000
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 100)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 14, 128)           38528
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3, 128)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 3, 128)            98816
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 14,012,673
# Trainable params: 180,673
# Non-trainable params: 13,832,000
# _________________________________________________________________
# Epoch 1/50
# 4500/4500 - 33s - loss: 0.6008 - accuracy: 0.6706 - val_loss: 0.5675 - val_accuracy: 0.7024
# Epoch 2/50
# 4500/4500 - 32s - loss: 0.5688 - accuracy: 0.6999 - val_loss: 0.5574 - val_accuracy: 0.7131
# Epoch 3/50
# 4500/4500 - 32s - loss: 0.5558 - accuracy: 0.7111 - val_loss: 0.5520 - val_accuracy: 0.7181
# Epoch 4/50
# 4500/4500 - 32s - loss: 0.5448 - accuracy: 0.7188 - val_loss: 0.5495 - val_accuracy: 0.7163
# Epoch 5/50
# 4500/4500 - 33s - loss: 0.5370 - accuracy: 0.7254 - val_loss: 0.5524 - val_accuracy: 0.7169
# Epoch 6/50
# 4500/4500 - 32s - loss: 0.5300 - accuracy: 0.7305 - val_loss: 0.5456 - val_accuracy: 0.7231
# Epoch 7/50
# 4500/4500 - 32s - loss: 0.5237 - accuracy: 0.7346 - val_loss: 0.5481 - val_accuracy: 0.7243
# Epoch 8/50
# 4500/4500 - 32s - loss: 0.5163 - accuracy: 0.7403 - val_loss: 0.5474 - val_accuracy: 0.7201
# Epoch 9/50
# 4500/4500 - 32s - loss: 0.5103 - accuracy: 0.7447 - val_loss: 0.5522 - val_accuracy: 0.7182
# Epoch 10/50
# 4500/4500 - 32s - loss: 0.5056 - accuracy: 0.7466 - val_loss: 0.5509 - val_accuracy: 0.7211
# Epoch 11/50
# 4500/4500 - 32s - loss: 0.5010 - accuracy: 0.7505 - val_loss: 0.5534 - val_accuracy: 0.7193
# Epoch 12/50
# 4500/4500 - 32s - loss: 0.4963 - accuracy: 0.7519 - val_loss: 0.5501 - val_accuracy: 0.7200
# Epoch 13/50
# 4500/4500 - 32s - loss: 0.4935 - accuracy: 0.7540 - val_loss: 0.5563 - val_accuracy: 0.7168
# Epoch 14/50
# 4500/4500 - 32s - loss: 0.4885 - accuracy: 0.7582 - val_loss: 0.5691 - val_accuracy: 0.7182
# Epoch 15/50
# 4500/4500 - 32s - loss: 0.4844 - accuracy: 0.7603 - val_loss: 0.5615 - val_accuracy: 0.7143
# Epoch 16/50
# 4500/4500 - 32s - loss: 0.4806 - accuracy: 0.7637 - val_loss: 0.5780 - val_accuracy: 0.7169
# Epoch 17/50
# 4500/4500 - 32s - loss: 0.4780 - accuracy: 0.7632 - val_loss: 0.5705 - val_accuracy: 0.7159
# Epoch 18/50
# 4500/4500 - 32s - loss: 0.4780 - accuracy: 0.7644 - val_loss: 0.5680 - val_accuracy: 0.7132
# Epoch 19/50
# 4500/4500 - 32s - loss: 0.4736 - accuracy: 0.7668 - val_loss: 0.5793 - val_accuracy: 0.7177
# Epoch 20/50
# 4500/4500 - 32s - loss: 0.4710 - accuracy: 0.7691 - val_loss: 0.5744 - val_accuracy: 0.7146
# Epoch 21/50
# 4500/4500 - 32s - loss: 0.4685 - accuracy: 0.7707 - val_loss: 0.5711 - val_accuracy: 0.7199
# Epoch 22/50
# 4500/4500 - 32s - loss: 0.4668 - accuracy: 0.7718 - val_loss: 0.5810 - val_accuracy: 0.7129
# Epoch 23/50
# 4500/4500 - 32s - loss: 0.4653 - accuracy: 0.7713 - val_loss: 0.5789 - val_accuracy: 0.7178
# Epoch 24/50
# 4500/4500 - 32s - loss: 0.4626 - accuracy: 0.7735 - val_loss: 0.5831 - val_accuracy: 0.7129
# Epoch 25/50
# 4500/4500 - 33s - loss: 0.4611 - accuracy: 0.7747 - val_loss: 0.5796 - val_accuracy: 0.7139
# Epoch 26/50
# 4500/4500 - 32s - loss: 0.4589 - accuracy: 0.7763 - val_loss: 0.5814 - val_accuracy: 0.7132
# Epoch 27/50
# 4500/4500 - 32s - loss: 0.4586 - accuracy: 0.7761 - val_loss: 0.5859 - val_accuracy: 0.7151
# Epoch 28/50
# 4500/4500 - 32s - loss: 0.4564 - accuracy: 0.7783 - val_loss: 0.5815 - val_accuracy: 0.7164
# Epoch 29/50
# 4500/4500 - 32s - loss: 0.4550 - accuracy: 0.7785 - val_loss: 0.5847 - val_accuracy: 0.7065
# Epoch 30/50
# 4500/4500 - 32s - loss: 0.4543 - accuracy: 0.7787 - val_loss: 0.5931 - val_accuracy: 0.7081
# Epoch 31/50
# 4500/4500 - 31s - loss: 0.4514 - accuracy: 0.7809 - val_loss: 0.5980 - val_accuracy: 0.7100
# Epoch 32/50
# 4500/4500 - 32s - loss: 0.4517 - accuracy: 0.7804 - val_loss: 0.5884 - val_accuracy: 0.7069
# Epoch 33/50
# 4500/4500 - 32s - loss: 0.4500 - accuracy: 0.7820 - val_loss: 0.5920 - val_accuracy: 0.7054
# Epoch 34/50
# 4500/4500 - 33s - loss: 0.4492 - accuracy: 0.7816 - val_loss: 0.5936 - val_accuracy: 0.7071
# Epoch 35/50
# 4500/4500 - 32s - loss: 0.4476 - accuracy: 0.7816 - val_loss: 0.6019 - val_accuracy: 0.7074
# Epoch 36/50
# 4500/4500 - 32s - loss: 0.4472 - accuracy: 0.7837 - val_loss: 0.5978 - val_accuracy: 0.7083
# Epoch 37/50
# 4500/4500 - 32s - loss: 0.4478 - accuracy: 0.7834 - val_loss: 0.6046 - val_accuracy: 0.7041
# Epoch 38/50
# 4500/4500 - 32s - loss: 0.4442 - accuracy: 0.7847 - val_loss: 0.6078 - val_accuracy: 0.7099
# Epoch 39/50
# 4500/4500 - 32s - loss: 0.4438 - accuracy: 0.7840 - val_loss: 0.6015 - val_accuracy: 0.7065
# Epoch 40/50
# 4500/4500 - 33s - loss: 0.4449 - accuracy: 0.7832 - val_loss: 0.6033 - val_accuracy: 0.7122
# Epoch 41/50
# 4500/4500 - 32s - loss: 0.4429 - accuracy: 0.7850 - val_loss: 0.6002 - val_accuracy: 0.7102
# Epoch 42/50
# 4500/4500 - 32s - loss: 0.4426 - accuracy: 0.7865 - val_loss: 0.5995 - val_accuracy: 0.7150
# Epoch 43/50
# 4500/4500 - 32s - loss: 0.4423 - accuracy: 0.7852 - val_loss: 0.6047 - val_accuracy: 0.7091
# Epoch 44/50
# 4500/4500 - 33s - loss: 0.4420 - accuracy: 0.7861 - val_loss: 0.6159 - val_accuracy: 0.7065
# Epoch 45/50
# 4500/4500 - 33s - loss: 0.4433 - accuracy: 0.7849 - val_loss: 0.6103 - val_accuracy: 0.7065
# Epoch 46/50
# 4500/4500 - 32s - loss: 0.4412 - accuracy: 0.7867 - val_loss: 0.6058 - val_accuracy: 0.7053
# Epoch 47/50
# 4500/4500 - 32s - loss: 0.4403 - accuracy: 0.7868 - val_loss: 0.6008 - val_accuracy: 0.7053
# Epoch 48/50
# 4500/4500 - 32s - loss: 0.4399 - accuracy: 0.7873 - val_loss: 0.6066 - val_accuracy: 0.7053
# Epoch 49/50
# 4500/4500 - 32s - loss: 0.4405 - accuracy: 0.7871 - val_loss: 0.6124 - val_accuracy: 0.7032
# Epoch 50/50
# 4500/4500 - 32s - loss: 0.4383 - accuracy: 0.7888 - val_loss: 0.6086 - val_accuracy: 0.7054
# Training Complete

# %% [markdown]
# ## Plotting the accuracy curves

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])

plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])

plt.figure()

# Expected Output
# A chart where the validation loss does not increase sharply!
# The graph should look like something below

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
